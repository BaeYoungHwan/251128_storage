# %%
from src.api_client import fetch_locker_usage

raw_data = fetch_locker_usage(1, 100)
raw_data

# %%
import sys

# %%
sys.executable
# Out:
# 'c:\\Users\\User\\Documents\\251128_물품보관함\\venv\\Scripts\\python.exe'
